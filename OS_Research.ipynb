# %%
import pandas as pd
import re
import gensim
import pprint
import sys 
import requests 
from datetime import datetime, timedelta 
import nltk 
import json

# %%
print(pd.__version__)
# Out:
# 1.4.4

# %%
api_base = 'https://services.nvd.nist.gov/rest/json/cves/2.0'
def get_data(query): 
    full_query = api_base + query
    r = requests.get(full_query)
    
    if r.status_code != 200:
        print('ERROR: Invalid request; returned {} for the following '
              'query:\n{}'.format(r.status_code, full_query))
        sys.exit(1)

    if not r.json():
        print('No data returned with the following query:')
        print(full_query)
        sys.exit(0)
    
    return r.json

# %%
api_base = 'https://services.nvd.nist.gov/rest/json/cves/1.0?'

endpoint = '?'
severity = 'cvssV3Severity=CRITICAL'
keyword = '&keyword=Windows' #macOS iOS Android'
resultsPerPage = '&resultsPerPage=2'
#cvssV3Severity=LOW 
#keywordSearch=Microsoft 

response = requests.get(api_base + severity + keyword) #+ resultsPerPage)
data = response.json()

#data = get_data(endpoint + 'cvssV3Severity=' + severity) #+ 'keywordSearch=' + search).
#type(data)
print(data['totalResults'])

#this statement works to obtain the description for each CVE
#print(data['result']['CVE_Items'][1]['cve']['description']['description_data'][0]['value'])

#print(json.dumps(data['result']['CVE_Items'][1]['cve'], indent=4))

#this statement works to return the published dates for each cve; change [1] to [count]
#print(json.dumps(data['result']['CVE_Items'][1]['publishedDate'], indent=4))
# Out:
# 629

# %%
api_base = 'https://services.nvd.nist.gov/rest/json/cves/1.0?'

endpoint = '?'
severity = 'cvssV3Severity=CRITICAL'
keyword = '&keyword=iOS' #macOS iOS Android'
isExactMatch = '&isExactMatch=true'
resultsPerPage = '&resultsPerPage='
per = 1000
#test = 1
#cvssV3Severity=LOW 
#keywordSearch=Microsoft 

response = requests.get(api_base + severity + keyword + isExactMatch + resultsPerPage + str(per))
data = response.json()


#response2 = requests.get(api_base + severity + keyword) #+ resultsPerPage)
#data2 = response.json()
#totalResultsCount = 1


#data = get_data(endpoint + 'cvssV3Severity=' + severity) #+ 'keywordSearch=' + search).
#type(data)
#print(type(json.dumps(data['result']['CVE_Items'][0], indent=4)))
print(data['totalResults'])
count = 0
while count < per:
    if count == data['totalResults']:
        break
    else: 
        print(str(count+1) + '   ' + data['result']['CVE_Items'][count]['cve']['description']
        ['description_data'][0]['value'])
        print(data['result']['CVE_Items'][count]['publishedDate'])
        print()
    count+=1

                 
                 #['cve']['description']['description_data']['value'], indent=4))

#count = 1
#while count < per+1:
#    print(json.dumps(data['result']['CVE_Items'][count], indent=4))
# Out:
# 240
# 1   In the thymeleaf-spring5:3.0.12 component, thymeleaf combined with specific scenarios in template injection may lead to remote code execution.
# 2021-11-09T12:15Z
#
# 2   A certificate validation issue existed in the handling of WKWebView. This issue was addressed with improved validation. This issue is fixed in tvOS 16.1, iOS 16.1 and iPadOS 16, macOS Ventura 13, watchOS 9.1. Processing a maliciously crafted certificate may lead to arbitrary code execution.
# 2022-11-01T20:15Z
#
# 3   An out-of-bounds write issue was addressed with improved bounds checking. This issue is fixed in tvOS 16.1, iOS 16.1 and iPadOS 16, macOS Ventura 13, watchOS 9.1. A remote user may be able to cause kernel code execution.
# 2022-11-01T20:15Z
#
# ...

# %%
response = requests.get('https://services.nvd.nist.gov/rest/json/cve/1.0/CVE-2021-40463')
data = response.json()
print(json.dumps(data, indent=4))
# Out:
# {'resultsPerPage': 1, 'startIndex': 0, 'totalResults': 1, 'result': {'CVE_data_type': 'CVE', 'CVE_data_format': 'MITRE', 'CVE_data_version': '4.0', 'CVE_data_timestamp': '2022-11-20T01:47Z', 'CVE_Items': [{'cve': {'data_type': 'CVE', 'data_format': 'MITRE', 'data_version': '4.0', 'CVE_data_meta': {'ID': 'CVE-2021-40463', 'ASSIGNER': 'secure@microsoft.com'}, 'problemtype': {'problemtype_data': [{'description': [{'lang': 'en', 'value': 'NVD-CWE-noinfo'}]}]}, 'references': {'reference_data': [{'url': 'https://portal.msrc.microsoft.com/en-US/security-guidance/advisory/CVE-2021-40463', 'name': 'https://portal.msrc.microsoft.com/en-US/security-guidance/advisory/CVE-2021-40463', 'refsource': 'MISC', 'tags': ['Patch', 'Vendor Advisory']}]}, 'description': {'description_data': [{'lang': 'en', 'value': 'Windows NAT Denial of Service Vulnerability'}]}}, 'configurations': {'CVE_data_version': '4.0', 'nodes': [{'operator': 'OR', 'children': [], 'cpe_match': [{'vulnerable': True, 'cpe23Uri': 'cpe:
# ...

# %%
API_HOST = 'https://access.redhat.com/hydra/rest/securitydata'
#API_HOST = 'https://access.redhat.com/security/security-updates/#/cve?q=windows&p=1&sort=cve_publicDate%20desc&rows=10&documentKind=Cve'
def get_data(query):

    full_query = API_HOST + query
    r = requests.get(full_query)

    if r.status_code != 200:
        print('ERROR: Invalid request; returned {} for the following '
              'query:\n{}'.format(r.status_code, full_query))
        sys.exit(1)

    if not r.json():
        print('No data returned with the following query:')
        print(full_query)
        sys.exit(0)

    return r.json()

# %%
endpoint = '/cve.json'
params_after_date = 'after=2016-12-31'
params_severity = 'severity=critical'
params_per_page = 'per_page=100'
page = 'page=4'

#data = get_data(endpoint + '?' + params_after_date + '&' + params_severity + '&' + params_per_page)
#data = get_data(endpoint + '?' + params_after_date + '&' + params_severity)

pg_count=1

'''
while pg_count<10: 
    data = get_data(endpoint + '?' + params_after_date + '&page=' + str(pg_count))
    i = 1
    for cve in data:
        print(i, cve['CVE'], cve['bugzilla_description'], cve['severity'], cve['public_date'])
        i+=1
    pg_count+=1
'''   

os_list = ['Windows','macOS','mac OS','iOS','Android']
text_corpus = []
full_list=[]
while pg_count<11: 
    data = get_data(endpoint + '?' + params_severity + '&page=' + str(pg_count))
    for cve in data:
        full_list.append(cve)
             
        cve_desc = cve['bugzilla_description']
        cve_desc = cve_desc.split(' ',1)
        cve_desc = cve_desc[1]
        
        for item in os_list: 
            if item in cve_desc: 
                text_corpus.append(cve_desc)
                print(cve_desc)
                
    pg_count+=1
# Out:
# Oracle JDK: unspecified vulnerability fixed in 7u191 and 8u181 (Windows DLL)
# OpenJDK: peering issues on Windows (AWT, 8167110)
# OpenJDK: incorrect menu handling on Windows (AWT, 8158993)
# No data returned with the following query:
# https://access.redhat.com/hydra/rest/securitydata/cve.json?severity=critical&page=4
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0

# %%
endpoint = '/cve.json'
params_severity = 'severity=critical'
params_per_page = 'per_page=100'
params_before_date='before=2022-11-30'

pg_count=1
os_list = ['Windows','macOS','mac OS','iOS','Android']

text_corpus = []
full_list=[]
while pg_count<2: 
    data = get_data(endpoint + '?' + 'page=' + str(pg_count))

    #data = get_data(endpoint + '?' + params_before_date + '&severity=' + params_severity + '&page=' + str(pg_count))
    #data = get_data(endpoint + '?' + params_severity + '&page=' + str(pg_count))
    #data = get_data(endpoint + '?' + params_after_date + '&page=' + str(pg_count))
    #data = get_data(endpoint + '?' + params_after_date + '&page=' + str(pg_count))
    
    for cve in data:
        
        #full_list.append(cve)
        if cve['severity'] == 'Critical':
            
            cve_desc = cve['bugzilla_description']
            cve_desc = cve_desc.split(' ',1)
            cve_desc = cve_desc[1]

            for item in os_list: 
                if item in cve_desc: 
                    text_corpus.append(cve_desc)
                    #print(cve_desc)
                
    pg_count+=1
    
text_corpus
# Out:
# []

# %%
endpoint = '/cve.json'
params_severity = 'severity=critical'
params_per_page = 'per_page=100'
params_before_date='before=2022-11-30'

pg_count=1
os_list = ['Windows','macOS','mac OS','iOS','Android']

text_corpus = []
full_list=[]
while pg_count<30: 
    data = get_data(endpoint + '?' + 'page=' + str(pg_count))

    #data = get_data(endpoint + '?' + params_before_date + '&severity=' + params_severity + '&page=' + str(pg_count))
    #data = get_data(endpoint + '?' + params_severity + '&page=' + str(pg_count))
    #data = get_data(endpoint + '?' + params_after_date + '&page=' + str(pg_count))
    #data = get_data(endpoint + '?' + params_after_date + '&page=' + str(pg_count))
    
    for cve in data:
        
        #full_list.append(cve)
        if cve['severity'] == 'critical':
            
            cve_desc = cve['bugzilla_description']
            cve_desc = cve_desc.split(' ',1)
            cve_desc = cve_desc[1]

            for item in os_list: 
                if item in cve_desc: 
                    text_corpus.append(cve_desc)
                    #print(cve_desc)
                
    pg_count+=1
    
text_corpus
# Out:
# ['Oracle JDK: unspecified vulnerability fixed in 7u191 and 8u181 (Windows DLL)',
#  'OpenJDK: peering issues on Windows (AWT, 8167110)',
#  'OpenJDK: incorrect menu handling on Windows (AWT, 8158993)']

# %%
https://access.redhat.com/security/security-updates/#/cve?q=windows&p=1&sort=cve_publicDate%20desc&rows=10&documentKind=Cve

# %%
https://access.redhat.com/security/security-updates/#/cve?q=windows&p=2&sort=cve_publicDate%20desc&rows=10&documentKind=Cve

# %%
https://access.redhat.com/security/security-updates/#/cve?q=windows&p=155&sort=cve_publicDate%20desc&rows=10&documentKind=Cve

# %%
endpoint = '/cve.json'
params_after_date = 'after=2010-01-01'
params_severity = 'severity=critical'
params_per_page = 'per_page=10'  #default len(data) is 1000
page = 'page=4'

#data = get_data(endpoint + '?' + params_after_date + '&' + params_severity + '&' + params_per_page)
#data = get_data(endpoint + '?' + params_after_date + '&' + params_severity)

pg_count=1

'''
while pg_count<10: 
    data = get_data(endpoint + '?' + params_after_date + '&page=' + str(pg_count))
    i = 1
    for cve in data:
        print(i, cve['CVE'], cve['bugzilla_description'], cve['severity'], cve['public_date'])
        i+=1
    pg_count+=1
'''   

os_list = ['Windows','macOS','mac OS','iOS','Android']


text_corpus = []
full_list=[]
while pg_count<2: 
#current len is 10k: 
    data = get_data(endpoint + '?' + params_after_date + '&page=' + str(pg_count))
    for cve in data:
        full_list.append(cve)
        
        if cve['severity'] == 'critical' or 'important' or 'low' or 'moderate':
            cve_desc = cve['bugzilla_description']
            cve_desc = cve_desc.split(' ',1)
            cve_desc = cve_desc[1]
            
            for item in os_list: 
                if item in cve_desc: 
                    text_corpus.append(cve_desc)
            

            #if 'iOS' in cve_desc: 
            text_corpus.append(cve_desc)
            print(cve_desc)
                
    pg_count+=1
text_corpus
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connection.py in _new_conn(self)
#     173         try:
# --> 174             conn = connection.create_connection(
#     175                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      71
# ---> 72     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      73         af, socktype, proto, canonname, sa = res
#
# ~/opt/anaconda3/lib/python3.9/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     953     addrlist = []
# --> 954     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     955         af, socktype, proto, canonname, sa = res
#
# ...

# %%
endpoint = '/cve.json'
params_after_date = 'after=2010-01-01'
params_severity = 'severity=critical'
params_per_page = 'per_page=10'  #default len(data) is 1000
page = 'page=4'

#data = get_data(endpoint + '?' + params_after_date + '&' + params_severity + '&' + params_per_page)
#data = get_data(endpoint + '?' + params_after_date + '&' + params_severity)

pg_count=1

'''
while pg_count<10: 
    data = get_data(endpoint + '?' + params_after_date + '&page=' + str(pg_count))
    i = 1
    for cve in data:
        print(i, cve['CVE'], cve['bugzilla_description'], cve['severity'], cve['public_date'])
        i+=1
    pg_count+=1
'''   

os_list = ['Windows','macOS','mac OS','iOS','Android']


text_corpus = []
full_list=[]
while pg_count<20: 
#current len is 10k: 
    data = get_data(endpoint + '?' + params_severity + '&page=3') #+ str(pg_count))
    for cve in data:
        cve_desc = cve['bugzilla_description']
        cve_desc = cve_desc.split(' ',1)
        cve_desc = cve_desc[1]
        #if cve['severity'] == 'critical':
        for item in os_list: 
            if item in cve_desc:
                full_list.append(cve)

        
    
    
    
"""
        if cve['severity'] == 'critical' or 'important' or 'low' or 'moderate':
            cve_desc = cve['bugzilla_description']
            cve_desc = cve_desc.split(' ',1)
            cve_desc = cve_desc[1]
            
            for item in os_list: 
                if item in cve_desc: 
                    text_corpus.append(cve_desc)
            

            #if 'iOS' in cve_desc: 
            text_corpus.append(cve_desc)
            print(cve_desc)
"""
pg_count+=1
print(len(full_list))
full_list
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/bp/ytk9rhpj6sx8l4gjls5gtrjh0000gn/T/ipykernel_3532/813866722.py in <module>
#      27 while pg_count<20:
#      28 #current len is 10k:
# ---> 29     data = get_data(endpoint + '?' + params_severity + '&page=3') #+ str(pg_count))
#      30     for cve in data:
#      31         cve_desc = cve['bugzilla_description']
#
# /var/folders/bp/ytk9rhpj6sx8l4gjls5gtrjh0000gn/T/ipykernel_3532/445890091.py in get_data(query)
#       4
#       5     full_query = API_HOST + query
# ----> 6     r = requests.get(full_query)
#       7
#       8     if r.status_code != 200:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/requests/api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# ...

# %%
a = 'hi my name is Android'
b = 'Android'
c = 'test'

# %%
b in a
# Out:
# True

# %%
c in a
# Out:
# False
